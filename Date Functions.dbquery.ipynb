-- %%
SELECT COUNT(DISTINCT `customer Id`) AS unique_customers,-- i am counting different customers in my table 
        Date,
        YEAR(Date) AS trans_year,-- Extract the year from the date column 

        MONTH(Date) AS trans_month, -- Extratc the month from the date column
        MONTHNAME(Date) As `trans_month-name`, --Extract the month name from the date column 

        DAY(Date) AS trans_day, --Extract the day from the date column 
        DAYNAME(Date) AS trans_day_name, --Extract the day from the date column

        SUM(`total amount`) As revenue,--calculate the total reveue 
        `Product Category`
FROM insurance.retention.retail_sales_dataset_csv
GROUP BY ALL;-- Grouping my data on all the columns that are not aggregated in my select statement
